# %%
import sys, os
sys.path.append(os.pardir)

os.environ["KERAS_BACKEND"]='tensorflow'
#import glob
import numpy as np


#from multiprocessing import Pool
#import multiprocessing as multi
#from data.func import load_npy, padding_mat
#sys.path.append('C:\\ProgramData\\Anaconda3\\pkgs\\pydot-1.2.3-py36hd4f83f9_0\\Lib\\site-packages')
#sys.path
x_train = np.load('/home/owner/デスクトップ/PythonFile/imdb/x_train_sort.npy')
x_test = np.load('/home/owner/デスクトップ/PythonFile/imdb/x_test_sort.npy')
y_train = np.load('/home/owner/デスクトップ/PythonFile/imdb/t_train.npy')
y_test = np.load('/home/owner/デスクトップ/PythonFile/imdb/t_test.npy')

embWeights=np.load('/home/owner/デスクトップ/PythonFile/imdb/weights.npy')
idx=np.load('/home/owner/デスクトップ/PythonFile/imdb/index.npy')
embWeights = embWeights[idx]


print('data loaded')

##

import keras
from keras.layers import Input, merge
from keras.models import Model
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout
from keras.layers import Embedding
from keras.layers import LSTM
import keras.backend as K
from keras.layers import Lambda, regularizers, Average

from keras.models import Model
from keras.layers import Input, Conv2D, Conv1D, MaxPooling2D, GlobalMaxPooling2D, GlobalMaxPooling1D, MaxPooling1D
from keras.layers.embeddings import Embedding
from keras.layers.recurrent import GRU
from keras.layers.wrappers import Bidirectional, TimeDistributed
from keras.layers.core import Dropout, Dense, Lambda, Masking
from keras.layers import merge, Layer, Activation, Dot, Concatenate, Flatten, Lambda

from keras.initializers import Identity,glorot_normal
from keras import regularizers

from keras import metrics

from keras.utils import plot_model



numSentencesPerDoc, numWordsPerSentence = x_train[0].shape[0], x_train[0].shape[1]
print(numSentencesPerDoc, numWordsPerSentence)
#print(x_train[0])

vocabSize, embeddingSize = embWeights.shape[0], embWeights.shape[1]
print(vocabSize, embeddingSize)

dropWordEmb = 0.25
recursiveClass = GRU

filters = 1 #embeddingSize*2
windowMin = 3
windowMax = 7
# dimOfSentimentMetrics = 5
batch_size = 256
epochs = 25
numGRU = 100
numDensePool=50

eta = 1e-9
dr = 0.2

##

#wordsInputs = Input(shape=(numWordsPerSentence,1), batch_shape=(numSentencesPerDoc,numWordsPerSentence,), dtype='int32', name='words_input')

x_in = Input( shape = ( numSentencesPerDoc, numWordsPerSentence ) , name='Input' )
#x_pop = Lambda( lambda x: x, output_shape=(numWordsPerSentence, ) , name='convert_shape' )( x_in )
    
#Layer functionの定義
embLayer = Embedding( input_dim=embWeights.shape[0], output_dim=embWeights.shape[1], weights=[embWeights]
                      ,mask_zero=True , trainable=False, embeddings_regularizer=regularizers.l2(0.0000001)
                      , input_length=numWordsPerSentence, name='Embedding' )


maxPooledPerDoc = []
convNets = []
maxPools = []

extraDimLayer = Lambda(lambda x: K.expand_dims(x), name='extraDimForConvo')
squeezeThirdLayer = Lambda(lambda x: K.squeeze(x, 3), name='squeezeThirdLayer')

for windowSize in range(windowMin,windowMax):
    name='word_mat_convo_win_size_'+str(windowSize)
    convNet = Conv2D(filters, kernel_size=(windowSize,embeddingSize), padding='valid', activation='relu'
                     ,strides=1, use_bias=True, input_shape=(numWordsPerSentence, embeddingSize, 1), data_format="channels_last",kernel_initializer=glorot_normal()
                     ,bias_regularizer=regularizers.l2(eta), kernel_regularizer=regularizers.l2(eta),name=name)
    convNets.append(convNet)
    name='word_mat_max_pool_win_size_'+str(windowSize)
    maxPool = MaxPooling1D(pool_size = int(numWordsPerSentence-windowSize-1), padding='valid')
    maxPools.append(maxPool)
    
    
for i in range(numSentencesPerDoc):
    maxPooledPerSentence = []
    x_pop = Lambda(lambda x: x[:,i], output_shape=(numWordsPerSentence, ) , name='convert_shape_'+'sentence'+str(i+1))( x_in )

    for j in range(windowMax-windowMin):   
        emb = embLayer(x_pop)
        emb = Dropout(dr,name='DropEmb'+str(i)+str(j))(emb)
        reshaped = extraDimLayer(emb)#Lambda(lambda x: K.expand_dims(x), name='extraDimForConvo_'+str(j)+'_sentence_'+str(i))(emb)
        name='word_mat_convo_win_size_'+str(j)+'_sentence_'+str(i)
        # wordsCNN = Conv2D(filters, kernel_size=(windowSize,embeddingSize), padding='valid', 
        #                    activation='relu', strides=1, use_bias=True, input_shape=(numWordsPerSentence, embeddingSize, 1), data_format="channels_last",
        #                    kernel_initializer=glorot_normal(),kernel_regularizer=regularizers.l2(),name=name)(reshaped)
        wordsCNN  = convNets[j](reshaped)
        wordsCNN = Dropout(dr,name='DropCNN'+str(i)+str(j))(wordsCNN)
        squeezed = squeezeThirdLayer(wordsCNN)#Lambda(lambda x: K.squeeze(x, 3), name='squeezeThirdLayer_'+str(j)+'_sentence_'+str(i))(wordsCNN)
        # newShape = (-1, int(squeezed.shape[1])*int(squeezed.shape[2]))
        # squeezed = Lambda(lambda x: K.reshape(x,shape=newShape), name ='squeezeDimForMaxPool'+str(i)+str(j))(squeezed)
        wordsCNNPooled=GlobalMaxPooling1D()(squeezed)
        #wordsCNNPooled= MaxPooling1D(pool_size = int(squeezed.shape[1]), padding='valid')(squeezed)
        maxPooledPerSentence.append(wordsCNNPooled)
        
    mergedPoolForSentence = Concatenate(axis = 1)(maxPooledPerSentence)
    newShape=(-1,1,int(mergedPoolForSentence.shape[1]))
    reshapedPoolForSentence = Lambda(lambda x: K.reshape(x,shape=newShape), name ='switch_axis_'+'sentence'+str(i+1)+'winSize'+str(j+windowMin))(mergedPoolForSentence)
    densePoolForSentence = Dense(numDensePool, bias_regularizer=regularizers.l2(eta),
                                 kernel_regularizer=regularizers.l2(eta), activation='softmax', use_bias=True)(reshapedPoolForSentence)

    densePoolForSentence = Dropout(dr,name='DropDense'+str(i))(densePoolForSentence)
    maxPooledPerDoc.append(densePoolForSentence)
    
#Naive Approach
averaged = Average()(maxPooledPerDoc) 
averaged = Lambda(lambda x:K.reshape(x,shape=(-1,int(averaged.shape[1])*int(averaged.shape[2]))), name ='attend_output')(averaged)
out_avg = Dense(1, activation='sigmoid', use_bias=True,
               kernel_regularizer=regularizers.l2(eta),bias_regularizer=regularizers.l2(eta))(averaged) 
    
#Apply Attention 
mergedPoolPerDoc = Concatenate(axis = 1)(maxPooledPerDoc)
biRnn_ = Bidirectional(GRU(numGRU,  return_sequences=True), merge_mode='concat')(mergedPoolPerDoc)
newShape = (-1, int(mergedPoolPerDoc.shape[1]), 2*int(mergedPoolPerDoc.shape[2]))
biRnn = Lambda(lambda x: K.reshape(x,shape=newShape), name ='biRnn_TF_Reminder')(biRnn_)

CONTEXT_DIM = int(int(biRnn.shape[1])*int(biRnn.shape[2])/2) 

eij = Dense(CONTEXT_DIM, use_bias=True, activation='tanh')(biRnn)
eij = Dense(CONTEXT_DIM, use_bias=False, activation='softmax')(eij)

weighted_input_ = merge([eij, biRnn], mode='dot', dot_axes=1)
weighted_input = Lambda(lambda x: K.reshape(x,shape=(-1,int(weighted_input_.shape[1])*int(weighted_input_.shape[2]))), name ='attend_output')(weighted_input_)

out = Dense(1, activation='sigmoid', use_bias=True)(weighted_input)

# mergedPoolPerDoc = Average()


##
model = Model(input=[x_in], output=[out])
# adadelta = keras.optimizers.Adadelta(lr=0.5, rho=0.95, epsilon=None, decay=0.0)
# model.compile(loss='binary_crossentropy',
#               optimizer=adadelta,
#               metrics=['accuracy'])
              
model.compile(loss='binary_crossentropy',
              optimizer=keras.optimizers.Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0),
              metrics=['accuracy'])

print("Model Build Complete")
##
model_avg = Model(input=[x_in], output=[out_avg])
model_avg.compile(loss='binary_crossentropy',
              optimizer=keras.optimizers.Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0),
              metrics=['accuracy'])

print("Average Model Build Complete")
##
'''
#save model to png file
from keras.utils import plot_model
plot_model( model, to_file='model.png' )

#モデルを保存せず直接可視化
from IPython.display import SVG
from keras.utils.vis_utils import model_to_dot
SVG( model_to_dot( model ).create( prog='dot', format='svg' ) )
'''
##
print('Train...')
# Out:
# data loaded
# 10 50
# 52306 300
# Model Build Complete
# Average Model Build Complete
# Train...
# /home/owner/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:155: UserWarning: The `merge` function is deprecated and will be removed after 08/2017. Use instead layers from `keras.layers.merge`, e.g. `add`, `concatenate`, etc.
# /home/owner/anaconda3/lib/python3.6/site-packages/keras/legacy/layers.py:464: UserWarning: The `Merge` layer is deprecated and will be removed after 08/2017. Use instead layers from `keras.layers.merge`, e.g. `add`, `concatenate`, etc.
#   name=name)
# /home/owner/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:164: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=[<tf.Tenso..., outputs=[<tf.Tenso...)`
# /home/owner/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:176: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=[<tf.Tenso..., outputs=[<tf.Tenso...)`

# %%
model_avg.load_weights('./imdb_AvgCnn.hdf5')

# %%
history = model_avg.fit(x_train, y_train, batch_size = batch_size, verbose=1, epochs=100 #epochs
                    ,validation_split=0.2, shuffle=True)
# Out:
# Train on 19852 samples, validate on 4964 samples
# Epoch 1/100
# 19852/19852 [==============================] - 9s 455us/step - loss: 0.3832 - acc: 0.8637 - val_loss: 0.4063 - val_acc: 0.8541
# Epoch 2/100
# 19852/19852 [==============================] - 6s 325us/step - loss: 0.3786 - acc: 0.8655 - val_loss: 0.4073 - val_acc: 0.8546
# Epoch 3/100
# 19852/19852 [==============================] - 6s 326us/step - loss: 0.3773 - acc: 0.8646 - val_loss: 0.4027 - val_acc: 0.8541
# Epoch 4/100
# 19852/19852 [==============================] - 6s 327us/step - loss: 0.3739 - acc: 0.8668 - val_loss: 0.4019 - val_acc: 0.8552
# Epoch 5/100
# 19852/19852 [==============================] - 7s 328us/step - loss: 0.3764 - acc: 0.8645 - val_loss: 0.4017 - val_acc: 0.8541
# Epoch 6/100
# 19852/19852 [==============================] - 6s 322us/step - loss: 0.3785 - acc: 0.8650 - val_loss: 0.4017 - val_acc: 0.8550
# Epoch 7/100
# 19852/19852 [==============================] - 6s 322us/step - loss: 0.3757 - acc: 0.8662 - val_loss: 0.4014 - val_acc: 0.8548
# Epoch 8/100
# 19852/19852 [==============================] - 7s 330us/step - loss: 0.3749 - acc: 0.8677 - val_loss: 0.4010 - val_acc: 0.8566
# Epoch 9/100
# 19852/19852 [==============================] - 7s 327us/step - loss: 0.3721 - acc: 0.8656 - val_loss: 0.4008 - val_acc: 0.8537
# Epoch 10/100
# 19852/19852 [==============================] - 6s 327us/step - loss: 0.
           0           Input[0][0]
# __________________________________________________________________________________________________
# convert_shape_sentence8 (Lambda (None, 50)           0           Input[0][0]
# __________________________________________________________________________________________________
# convert_shape_sentence9 (Lambda (None, 50)           0           Input[0][0]
# __________________________________________________________________________________________________
# convert_shape_sentence10 (Lambd (None, 50)           0           Input[0][0]
# __________________________________________________________________________________________________
# Embedding (Embedding)           (None, 50, 300)      15691800    convert_shape_sentence1[0][0]
#                                                                  convert_shape_sentence1[0][0]
#                                                                  convert_shape_sentence1[0][0]
#                                                                  convert_shape_sentence1[0][0]
#                                                                  convert_shape_sentence2[0][0]
#                                                                  convert_shape_sentence2[0][0]
#                                                                  convert_shape_sentence2[0][0]
#                                                                  convert_shape_sentence2[0][0]
#                                                                  convert_shape_sentence3[0][0]
#                                                                  convert_shape_sentence3[0][0]
#                                                                  convert_shape_sentence3[0][0]
#                                                                  convert_shape_sentence3[0][0]
#                                                                  convert_shape_sentence4[0][0]
#                                                                  convert_shape_sentence4[0][0]
#                                                                  convert_shape_sentence4[0][0]
#                                                                  convert_shape_sentence4[0][0]
#                                                                  convert_shape_sentence5[0][0]
#                                                                  convert_shape_sentence5[0][0]
#                                                                  convert_shape_sentence5[0][0]
#                                                                  convert_shape_sentence5[0][0]
#                                                                  convert_shape_sentence6[0][0]
#                                                                  convert_shape_sentence6[0][0]
#                                                                  convert_shape_sentence6[0][0]
#                                                                  convert_shape_sentence6[0][0]
#                                                                  convert_shape_sentence7[0][0]
#                                                                  convert_shape_sentence7[0][0]
#                                                                  convert_shape_sentence7[0][0]
#                                                                  convert_shape_sentence7[0][0]
#                                                                  convert_shape_sentence8[0][0]
#                                                                  convert_shape_sentence8[0][0]
#                                                                  convert_shape_sentence8[0][0]
#                                                                  convert_shape_sentence8[0][0]
#                                                                  convert_shape_sentence9[0][0]
#                                                                  convert_shape_sentence9[0][0]
#                                                                  convert_shape_sentence9[0][0]
#                                                                  convert_shape_sentence9[0][0]
#                                                                  convert_shape_sentence10[0][0]
#                                                                  convert_shape_sentence10[0][0]
#                                                                  convert_shape_sentence10[0][0]
#                                                                  convert_shape_sentence10[0][0]
# __________________________________________________________________________________________________
# extraDimForConvo (Lambda)       (None, 50, 300, 1)   0           Embedding[0][0]
#                                                                  Embedding[1][0]
#                                                                  Embedding[2][0]
#                                                                  Embedding[3][0]
#                                                                  Embedding[4][0]
#                                                                  Embedding[5][0]
#                                                                  Embedding[6][0]
#                                                                  Embedding[7][0]
#                                                                  Embedding[8][0]
#                                                                  Embedding[9][0]
#                                                                  Embedding[10][0]
#                                                                  Embedding[11][0]
#                                                                  Embedding[12][0]
#                                                                  Embedding[13][0]
#                                                                  Embedding[14][0]
#                                                                  Embedding[15][0]
#                                                                  Embedding[16][0]
#                                                                  Embedding[17][0]
#                                                                  Embedding[18][0]
#                                                                  Embedding[19][0]
#                                                                  Embedding[20][0]
#                                                                  Embedding[21][0]
#                                                                  Embedding[22][0]
#                                                                  Embedding[23][0]
#                                                                  Embedding[24][0]
#                                                                  Embedding[25][0]
#                                                                  Embedding[26][0]
#                                                                  Embedding[27][0]
#                                                                  Embedding[28][0]
#                                                                  Embedding[29][0]
#                                                                  Embedding[30][0]
#                                                                  Embedding[31][0]
#                                                                  Embedding[32][0]
#                                                                  Embedding[33][0]
#                                                                  Embedding[34][0]
#                                                                  Embedding[35][0]
#                                                                  Embedding[36][0]
#                                                                  Embedding[37][0]
#                                                                  Embedding[38][0]
#                                                                  Embedding[39][0]
# __________________________________________________________________________________________________
# word_mat_convo_win_size_3 (Conv (None, 48, 1, 1)     901         extraDimForConvo[0][0]
#                                                                  extraDimForConvo[4][0]
#                                                                  extraDimForConvo[8][0]
#                                                                  extraDimForConvo[12][0]
#                                                                  extraDimForConvo[16][0]
#                                                                  extraDimForConvo[20][0]
#                                                                  extraDimForConvo[24][0]
#                                                                  extraDimForConvo[28][0]
#                                                                  extraDimForConvo[32][0]
#                                                                  extraDimForConvo[36][0]
# __________________________________________________________________________________________________
# word_mat_convo_win_size_4 (Conv (None, 47, 1, 1)     1201        extraDimForConvo[1][0]
#                                                                  extraDimForConvo[5][0]
#                                                                  extraDimForConvo[9][0]
#                                                                  extraDimForConvo[13][0]
#                                                                  extraDimForConvo[17][0]
#                                                                  extraDimForConvo[21][0]
#                                                                  extraDimForConvo[25][0]
#                                                                  extraDimForConvo[29][0]
#                                                                  extraDimForConvo[33][0]
#                                                                  extraDimForConvo[37][0]
# __________________________________________________________________________________________________
# word_mat_convo_win_size_5 (Conv (None, 46, 1, 1)     1501        extraDimForConvo[2][0]
#                                                                  extraDimForConvo[6][0]
#                                                                  extraDimForConvo[10][0]
#                                                                  extraDimForConvo[14][0]
#                                                                  extraDimForConvo[18][0]
#                                                                  extraDimForConvo[22][0]
#                                                                  extraDimForConvo[26][0]
#                                                                  extraDimForConvo[30][0]
#                                                                  extraDimForConvo[34][0]
#                                                                  extraDimForConvo[38][0]
# __________________________________________________________________________________________________
# word_mat_convo_win_size_6 (Conv (None, 45, 1, 1)     1801        extraDimForConvo[3][0]
#                                                                  extraDimForConvo[7][0]
#                                                                  extraDimForConvo[11][0]
#                                                                  extraDimForConvo[15][0]
#                                                                  extraDimForConvo[19][0]
#                                                                  extraDimForConvo[23][0]
#                                                                  extraDimForConvo[27][0]
#                                                                  extraDimForConvo[31][0]
#                                                                  extraDimForConvo[35][0]
#                                                                  extraDimForConvo[39][0]
# __________________________________________________________________________________________________
# squeezeThirdLayer (Lambda)      multiple             0           word_mat_convo_win_size_3[0][0]
#                                                                  word_mat_convo_win_size_4[0][0]
#                                                                  word_mat_convo_win_size_5[0][0]
#                                                                  word_mat_convo_win_size_6[0][0]
#                                                                  word_mat_convo_win_size_3[1][0]
#                                                                  word_mat_convo_win_size_4[1][0]
#                                                                  word_mat_convo_win_size_5[1][0]
#                                                                  word_mat_convo_win_size_6[1][0]
#                                                                  word_mat_convo_win_size_3[2][0]
#                                                                  word_mat_convo_win_size_4[2][0]
#                                                                  word_mat_convo_win_size_5[2][0]
#                                                                  word_mat_convo_win_size_6[2][0]
#                                                                  word_mat_convo_win_size_3[3][0]
#                                                                  word_mat_convo_win_size_4[3][0]
#                                                                  word_mat_convo_win_size_5[3][0]
#                                                                  word_mat_convo_win_size_6[3][0]
#                                                                  word_mat_convo_win_size_3[4][0]
#                                                                  word_mat_convo_win_size_4[4][0]
#                                                                  word_mat_convo_win_size_5[4][0]
#                                                                  word_mat_convo_win_size_6[4][0]
#                                                                  word_mat_convo_win_size_3[5][0]
#                                                                  word_mat_convo_win_size_4[5][0]
#                                                                  word_mat_convo_win_size_5[5][0]
#                                                                  word_mat_convo_win_size_6[5][0]
#                                                                  word_mat_convo_win_size_3[6][0]
#                                                                  word_mat_convo_win_size_4[6][0]
#                                                                  word_mat_convo_win_size_5[6][0]
#                                                                  word_mat_convo_win_size_6[6][0]
#                                                                  word_mat_convo_win_size_3[7][0]
#                                                                  word_mat_convo_win_size_4[7][0]
#                                                                  word_mat_convo_win_size_5[7][0]
#                                                                  word_mat_convo_win_size_6[7][0]
#                                                                  word_mat_convo_win_size_3[8][0]
#                                                                  word_mat_convo_win_size_4[8][0]
#                                                                  word_mat_convo_win_size_5[8][0]
#                                                                  word_mat_convo_win_size_6[8][0]
#                                                                  word_mat_convo_win_size_3[9][0]
#                                                                  word_mat_convo_win_size_4[9][0]
#                                                                  word_mat_convo_win_size_5[9][0]
#                                                                  word_mat_convo_win_size_6[9][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_41 (Global (None, 1)            0           squeezeThirdLayer[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_42 (Global (None, 1)            0           squeezeThirdLayer[1][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_43 (Global (None, 1)            0           squeezeThirdLayer[2][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_44 (Global (None, 1)            0           squeezeThirdLayer[3][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_45 (Global (None, 1)            0           squeezeThirdLayer[4][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_46 (Global (None, 1)            0           squeezeThirdLayer[5][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_47 (Global (None, 1)            0           squeezeThirdLayer[6][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_48 (Global (None, 1)            0           squeezeThirdLayer[7][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_49 (Global (None, 1)            0           squeezeThirdLayer[8][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_50 (Global (None, 1)            0           squeezeThirdLayer[9][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_51 (Global (None, 1)            0           squeezeThirdLayer[10][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_52 (Global (None, 1)            0           squeezeThirdLayer[11][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_53 (Global (None, 1)            0           squeezeThirdLayer[12][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_54 (Global (None, 1)            0           squeezeThirdLayer[13][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_55 (Global (None, 1)            0           squeezeThirdLayer[14][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_56 (Global (None, 1)            0           squeezeThirdLayer[15][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_57 (Global (None, 1)            0           squeezeThirdLayer[16][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_58 (Global (None, 1)            0           squeezeThirdLayer[17][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_59 (Global (None, 1)            0           squeezeThirdLayer[18][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_60 (Global (None, 1)            0           squeezeThirdLayer[19][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_61 (Global (None, 1)            0           squeezeThirdLayer[20][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_62 (Global (None, 1)            0           squeezeThirdLayer[21][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_63 (Global (None, 1)            0           squeezeThirdLayer[22][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_64 (Global (None, 1)            0           squeezeThirdLayer[23][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_65 (Global (None, 1)            0           squeezeThirdLayer[24][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_66 (Global (None, 1)            0           squeezeThirdLayer[25][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_67 (Global (None, 1)            0           squeezeThirdLayer[26][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_68 (Global (None, 1)            0           squeezeThirdLayer[27][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_69 (Global (None, 1)            0           squeezeThirdLayer[28][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_70 (Global (None, 1)            0           squeezeThirdLayer[29][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_71 (Global (None, 1)            0           squeezeThirdLayer[30][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_72 (Global (None, 1)            0           squeezeThirdLayer[31][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_73 (Global (None, 1)            0           squeezeThirdLayer[32][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_74 (Global (None, 1)            0           squeezeThirdLayer[33][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_75 (Global (None, 1)            0           squeezeThirdLayer[34][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_76 (Global (None, 1)            0           squeezeThirdLayer[35][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_77 (Global (None, 1)            0           squeezeThirdLayer[36][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_78 (Global (None, 1)            0           squeezeThirdLayer[37][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_79 (Global (None, 1)            0           squeezeThirdLayer[38][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_80 (Global (None, 1)            0           squeezeThirdLayer[39][0]
# __________________________________________________________________________________________________
# concatenate_12 (Concatenate)    (None, 4)            0           global_max_pooling1d_41[0][0]
#                                                                  global_max_pooling1d_42[0][0]
#                                                                  global_max_pooling1d_43[0][0]
#                                                                  global_max_pooling1d_44[0][0]
# __________________________________________________________________________________________________
# concatenate_13 (Concatenate)    (None, 4)            0           global_max_pooling1d_45[0][0]
#                                                                  global_max_pooling1d_46[0][0]
#                                                                  global_max_pooling1d_47[0][0]
#                                                                  global_max_pooling1d_48[0][0]
# __________________________________________________________________________________________________
# concatenate_14 (Concatenate)    (None, 4)            0           global_max_pooling1d_49[0][0]
#                                                                  global_max_pooling1d_50[0][0]
#                                                                  global_max_pooling1d_51[0][0]
#                                                                  global_max_pooling1d_52[0][0]
# __________________________________________________________________________________________________
# concatenate_15 (Concatenate)    (None, 4)            0           global_max_pooling1d_53[0][0]
#                                                                  global_max_pooling1d_54[0][0]
#                                                                  global_max_pooling1d_55[0][0]
#                                                                  global_max_pooling1d_56[0][0]
# __________________________________________________________________________________________________
# concatenate_16 (Concatenate)    (None, 4)            0           global_max_pooling1d_57[0][0]
#                                                                  global_max_pooling1d_58[0][0]
#                                                                  global_max_pooling1d_59[0][0]
#                                                                  global_max_pooling1d_60[0][0]
# __________________________________________________________________________________________________
# concatenate_17 (Concatenate)    (None, 4)            0           global_max_pooling1d_61[0][0]
#                                                                  global_max_pooling1d_62[0][0]
#                                                                  global_max_pooling1d_63[0][0]
#                                                                  global_max_pooling1d_64[0][0]
# __________________________________________________________________________________________________
# concatenate_18 (Concatenate)    (None, 4)            0           global_max_pooling1d_65[0][0]
#                                                                  global_max_pooling1d_66[0][0]
#                                                                  global_max_pooling1d_67[0][0]
#                                                                  global_max_pooling1d_68[0][0]
# __________________________________________________________________________________________________
# concatenate_19 (Concatenate)    (None, 4)            0           global_max_pooling1d_69[0][0]
#                                                                  global_max_pooling1d_70[0][0]
#                                                                  global_max_pooling1d_71[0][0]
#                                                                  global_max_pooling1d_72[0][0]
# __________________________________________________________________________________________________
# concatenate_20 (Concatenate)    (None, 4)            0           global_max_pooling1d_73[0][0]
#                                                                  global_max_pooling1d_74[0][0]
#                                                                  global_max_pooling1d_75[0][0]
#                                                                  global_max_pooling1d_76[0][0]
# __________________________________________________________________________________________________
# concatenate_21 (Concatenate)    (None, 4)            0           global_max_pooling1d_77[0][0]
#                                                                  global_max_pooling1d_78[0][0]
#                                                                  global_max_pooling1d_79[0][0]
#                                                                  global_max_pooling1d_80[0][0]
# __________________________________________________________________________________________________
# switch_axis_sentence1winSize6 ( (None, 1, 4)         0           concatenate_12[0][0]
# __________________________________________________________________________________________________
# switch_axis_sentence2winSize6 ( (None, 1, 4)         0           concatenate_13[0][0]
# __________________________________________________________________________________________________
# switch_axis_sentence3winSize6 ( (None, 1, 4)         0           concatenate_14[0][0]
# __________________________________________________________________________________________________
# switch_axis_sentence4winSize6 ( (None, 1, 4)         0           concatenate_15[0][0]
# __________________________________________________________________________________________________
# switch_axis_sentence5winSize6 ( (None, 1, 4)         0           concatenate_16[0][0]
# __________________________________________________________________________________________________
# switch_axis_sentence6winSize6 ( (None, 1, 4)         0           concatenate_17[0][0]
# __________________________________________________________________________________________________
# switch_axis_sentence7winSize6 ( (None, 1, 4)         0           concatenate_18[0][0]
# __________________________________________________________________________________________________
# switch_axis_sentence8winSize6 ( (None, 1, 4)         0           concatenate_19[0][0]
# __________________________________________________________________________________________________
# switch_axis_sentence9winSize6 ( (None, 1, 4)         0           concatenate_20[0][0]
# __________________________________________________________________________________________________
# switch_axis_sentence10winSize6  (None, 1, 4)         0           concatenate_21[0][0]
# __________________________________________________________________________________________________
# dense_15 (Dense)                (None, 1, 50)        250         switch_axis_sentence1winSize6[0][
# __________________________________________________________________________________________________
# dense_16 (Dense)                (None, 1, 50)        250         switch_axis_sentence2winSize6[0][
# __________________________________________________________________________________________________
# dense_17 (Dense)                (None, 1, 50)        250         switch_axis_sentence3winSize6[0][
# __________________________________________________________________________________________________
# dense_18 (Dense)                (None, 1, 50)        250         switch_axis_sentence4winSize6[0][
# __________________________________________________________________________________________________
# dense_19 (Dense)                (None, 1, 50)        250         switch_axis_sentence5winSize6[0][
# __________________________________________________________________________________________________
# dense_20 (Dense)                (None, 1, 50)        250         switch_axis_sentence6winSize6[0][
# __________________________________________________________________________________________________
# dense_21 (Dense)                (None, 1, 50)        250         switch_axis_sentence7winSize6[0][
# __________________________________________________________________________________________________
# dense_22 (Dense)                (None, 1, 50)        250         switch_axis_sentence8winSize6[0][
# __________________________________________________________________________________________________
# dense_23 (Dense)                (None, 1, 50)        250         switch_axis_sentence9winSize6[0][
# __________________________________________________________________________________________________
# dense_24 (Dense)                (None, 1, 50)        250         switch_axis_sentence10winSize6[0]
# __________________________________________________________________________________________________
# average_2 (Average)             (None, 1, 50)        0           dense_15[0][0]
#                                                                  dense_16[0][0]
#                                                                  dense_17[0][0]
#                                                                  dense_18[0][0]
#                                                                  dense_19[0][0]
#                                                                  dense_20[0][0]
#                                                                  dense_21[0][0]
#                                                                  dense_22[0][0]
#                                                                  dense_23[0][0]
#                                                                  dense_24[0][0]
# __________________________________________________________________________________________________
# attend_output (Lambda)          (None, 50)           0           average_2[0][0]
# __________________________________________________________________________________________________
# dense_25 (Dense)                (None, 1)            51          attend_output[0][0]
# ==================================================================================================
# Total params: 15,699,755
# Trainable params: 15,699,755
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
#save model to png file
from keras.utils import plot_model
plot_model( model, to_file='model.png' )

#モデルを保存せず直接可視化
from IPython.display import SVG
from keras.utils.vis_utils import model_to_dot
SVG( model_to_dot( model ).create( prog='dot', format='svg' ) )

# %%
len(b)
# Out:
# 31

# %%
plt.hist(b[39],bins=100)
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec

# %%
#title = ['Win LSTM', 'Wout LSTM', 'Bias of LSTM', 'W for LSTM Output', 'W Relu for 3 time Vectors', 'W Linear Regression']
def plot_weights(w):
    l = len(w)
    fig = plt.figure(figsize=(30,16))
    gs = gridspec.GridSpec(int(l/2+1),2)
    
    for i in range(l):
        j = int( i/2 )
        k = i%2
        if k==0:
            ax = plt.subplot(gs[j,k])
            ax.hist( w[i].flatten() ,bins=100 ,range=(-0.5,0.5) )
            #ax.set_title(title[i])
        else:
            ax = plt.subplot(gs[j,k])
            ax.hist( w[i].flatten() ,bins=100 ,range=(-0.5,0.5) )
            #ax.set_title(title[i])
    plt.show()

# %%
plot_weights(b)

# %%
#plot history
import matplotlib.pyplot as plt
def plot_history(history):
    # 精度の履歴をプロット
    plt.plot(history.history['acc'],label="accuracy")
    plt.plot(history.history['val_acc'],"o-",label="val_acc")
    plt.title('model accuracy')
    plt.xlabel('epoch')
    plt.ylabel('accuracy')
    plt.legend(loc="lower right")
    plt.show()

    # 損失の履歴をプロット
    plt.plot(history.history['loss'],label="loss",)
    plt.plot(history.history['val_loss'],"o-",label="val_loss")
    plt.title('model loss')
    plt.xlabel('epoch')
    plt.ylabel('loss')
    plt.legend(loc='lower right')
    plt.show()

# %%
plot_history(history)

# %%
model_avg.save_weights('./imdb_AvgCnn.hdf5')

# %%
score=model_avg.evaluate(x_test, y_test)
# Out:
# 24808/24808 [==============================] - 9s 375us/step

# %%
print(score[0],score[1])
# Out:
# 0.380358204457 0.862504030958
