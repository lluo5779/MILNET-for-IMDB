# %%
import sys, os
sys.path.append(os.pardir)

os.environ["KERAS_BACKEND"]='tensorflow'
#import glob
import numpy as np


weight_choice = input('Which weights to choose? 1:normal 2:lle 3:iso')



#from multiprocessing import Pool
#import multiprocessing as multi
#from data.func import load_npy, padding_mat
#sys.path.append('C:\\ProgramData\\Anaconda3\\pkgs\\pydot-1.2.3-py36hd4f83f9_0\\Lib\\site-packages')
#sys.path


path_to_15_40 = 'milnet+edu/data/Preprocessed/15words+40sent/'
path_to_20_50 = 'milnet+edu/data/Preprocessed/20words+50sent/'

path =path_to_15_40

x_train = np.load('/home/owner/デスクトップ/'+path+'train_data_features_sorted.npy')#np.load('/home/owner/デスクトップ/PythonFile/imdb/x_train_sort.npy')
y_train = np.load('/home/owner/デスクトップ/'+path+'train_data_scores_binary.npy')#np.load('/home/owner/デスクトップ/PythonFile/imdb/x_test_sort.npy')
#print(x_test)

x_test = np.load('/home/owner/デスクトップ/'+path+'test_data_features_sorted.npy')#np.load('/home/owner/デスクトップ/PythonFile/imdb/t_train.npy')
y_test = np.load('/home/owner/デスクトップ/'+path+'test_data_scores_binary.npy')#np.load('/home/owner/デスクトップ/PythonFile/imdb/t_test.npy')

x_valid = np.load('/home/owner/デスクトップ/'+path+'validation_data_features_sorted.npy')
y_valid = np.load('/home/owner/デスクトップ/'+path+'validation_data_scores_binary.npy')

#train_idx = np.load('/home/owner/デスクトップ/'+path+'train_data_idx_binary_only.npy')
#test_idx = np.load('/home/owner/デスクトップ/'+path+'test_data_idx_binary_only.npy')
#valid_idx = np.load('/home/owner/デスクトップ/'+path+'validation_data_idx_binary_only.npy')

#print(len(train_idx))
#x_train = x_train[train_idx]
#y_train = y_train[train_idx]
#print(len(x_train))
#print(len(y_train))

#x_test = x_test[test_idx]
#y_test = y_test[test_idx]

#x_valid = x_valid[valid_idx]
#y_valid = y_valid[valid_idx]

#print(x_valid)

#word_idx=np.load( '/home/owner/デスクトップ/'+ path +'vocab_idx.npy')
#print(idx)
#mani_choice = input('Which weights to choose? 1:normal 2:lle 3:iso ')
if (int(weight_choice)==1):
    embWeights=np.load( '/home/owner/デスクトップ/'+ path +'weights.npy')#np.load('/home/owner/デスクトップ/PythonFile/imdb/weights.npy')
elif (int(weight_choice)==2):
    embWeights=np.load( '/home/owner/デスクトップ/milnet+edu/data/manifold_weights/' + 'weights_LLE_(15,40)_(1000,20,300).npy')#np.load('/home/owner/デスクトップ/PythonFile/imdb/weights.npy')
elif (int(weight_choice)==3):
     embWeights=np.load( '/home/owner/デスクトップ/milnet+edu/data/manifold_weights/' + 'weights_Isomap_(15,40)_(1000,20,300).npy')

#print(len(word_idx))
print(y_test)

print('data loaded')



import keras
from keras.layers import Input, merge
from keras.models import Model
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout
from keras.layers import Embedding
from keras.layers import LSTM
import keras.backend as K
from keras.layers import Lambda, regularizers, Average
from keras.layers import RepeatVector, Permute, Multiply

from keras.models import Model
from keras.layers import Input, Conv2D, Conv1D, MaxPooling2D, GlobalMaxPooling2D, GlobalMaxPooling1D, MaxPooling1D
from keras.layers.embeddings import Embedding
from keras.layers.recurrent import GRU
from keras.layers.wrappers import Bidirectional, TimeDistributed
from keras.layers.core import Dropout, Dense, Lambda, Masking
from keras.layers import merge, Layer, Activation, Dot, Concatenate, Flatten, Lambda

from keras.initializers import Identity,glorot_normal
from keras import regularizers

from keras import metrics

from keras.utils import plot_model
# Out:
# Which weights to choose? 1:normal 2:lle 3:iso2
# [0 0 0 ... 1 1 1]
# data loaded
# /home/owner/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# /home/owner/anaconda3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: compiletime version 3.5 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.6
#   return f(*args, **kwds)

# %% [markdown]
# li = [x_train.tolist(), x_test.tolist(), x_valid.tolist()]
# for idx in range(3):
#     features = li[idx]
#     print(len(features))
#     for i in range(len(features)):
#         #print(len(features[i]))
#         if len(features[i])!=40:
#                 print('i:'+str(i)+'   ;;;;;;;;;;;;;;;;;;;;;')
#                 print(len(features[i]))
#                 li[idx][i].append(li[idx][i][-1])
#         for j in range(len(features[i])):
#
#             #print(len(features[i][j]))
#             if len(features[i][j])!= 15:
#                 print('i:'+str(i)+'j:'+str(j)+'   *************************')
#
# x_train=np.asarray(li[0])
# x_test=np.asarray(li[1])
# x_valid=np.asarray(li[2])

# %%
print(x_train.shape, x_test.shape, x_valid.shape)
print(y_train.shape, y_test.shape, y_valid.shape)
# Out:
# (210642, 40, 15) (25510, 40, 15) (25206, 40, 15)
# (210642,) (25510,) (25206,)

# %%
numSentencesPerDoc, numWordsPerSentence = x_train[0].shape[0], x_train[0].shape[1]
print(numSentencesPerDoc, numWordsPerSentence)
#print(x_train[0])

vocabSize, embeddingSize = embWeights.shape[0], embWeights.shape[1]
print(vocabSize, embeddingSize)

dropWordEmb = 0.25
recursiveClass = GRU

filters = 100 #embeddingSize*2
windowMin = 3
windowMax = 7# dimOfSentimentMetrics = 5
batch_size = 200
#epochs = 25
dimGRU = 50
numDensePool=10
eta = 1e-4
dr = 0.5

##

#wordsInputs = Input(shape=(numWordsPerSentence,1), batch_shape=(numSentencesPerDoc,numWordsPerSentence,), dtype='int32', name='words_input')

x_in = Input( shape = ( numSentencesPerDoc, numWordsPerSentence ) , name='Input' )
#x_pop = Lambda( lambda x: x, output_shape=(numWordsPerSentence, ) , name='convert_shape' )( x_in )
    
#Layer functionの定義
embLayer = Embedding( input_dim=embWeights.shape[0], output_dim=embWeights.shape[1], weights=[embWeights]
                      ,mask_zero=False , trainable=False, embeddings_regularizer=regularizers.l2(0.0000001)
                      , input_length=numWordsPerSentence, name='Embedding' )

maxPooledPerDoc = []
convNets = []
maxPools = []
scoresForSentences = []


extraDimLayer = Lambda(lambda x: K.expand_dims(x), name='extraDimForConvo')
squeezeThirdLayer = Lambda(lambda x: K.squeeze(x, 3), name='squeezeThirdLayer')

for windowSize in range(windowMin,windowMax):
    name='word_mat_convo_win_size_'+str(windowSize)
    #convNet = Conv2D(filters, kernel_size=(windowSize,embeddingSize), padding='valid', activation='relu'
    #                 ,strides=1, use_bias=True, input_shape=(numWordsPerSentence, embeddingSize, 1), data_format="channels_last",kernel_initializer=glorot_normal()
    #                 ,bias_regularizer=regularizers.l2(eta), kernel_regularizer=regularizers.l2(eta),name=name)
    convNet = Conv1D(filters=filters, kernel_size=windowSize, padding='valid', activation='relu', strides=1,use_bias=False,
                    kernel_regularizer=regularizers.l2(eta), name = name)
    convNets.append(convNet)
    name='word_mat_max_pool_win_size_'+str(windowSize)
    maxPool = MaxPooling1D(pool_size = int(numWordsPerSentence-windowSize-1), padding='valid')
    maxPools.append(maxPool)
    
    
for i in range(numSentencesPerDoc):
    maxPooledPerSentence = []
    x_pop = Lambda(lambda x: x[:,i], output_shape=(numWordsPerSentence, ) , name='convert_shape_'+'sentence'+str(i+1))( x_in )

    for j in range(windowMax-windowMin):   
        emb = embLayer(x_pop)
        #emb = Dropout(dr,name='DropEmb'+str(i)+str(j))(emb)
        #reshaped = extraDimLayer(emb)#Lambda(lambda x: K.expand_dims(x), name='extraDimForConvo_'+str(j)+'_sentence_'+str(i))(emb)
        #name='word_mat_convo_win_size_'+str(j)+'_sentence_'+str(i)
        #wordsCNN = Conv2D(filters, kernel_size=(windowSize,embeddingSize), padding='valid', 
        #                    activation='relu', strides=1, use_bias=True, input_shape=(numWordsPerSentence, embeddingSize, 1), data_format="channels_last",
        #                    kernel_initializer=glorot_normal(),kernel_regularizer=regularizers.l2(),name=name)(reshaped)
        wordsCNN  = convNets[j](emb)
        wordsCNN = Dropout(dr,name='DropCNN'+str(i)+str(j))(wordsCNN)
        #squeezed = squeezeThirdLayer(wordsCNN)#Lambda(lambda x: K.squeeze(x, 3), name='squeezeThirdLayer_'+str(j)+'_sentence_'+str(i))(wordsCNN)
        # newShape = (-1, int(squeezed.shape[1])*int(squeezed.shape[2]))
        # squeezed = Lambda(lambda x: K.reshape(x,shape=newShape), name ='squeezeDimForMaxPool'+str(i)+str(j))(squeezed)
        #wordsCNNPooled=GlobalMaxPooling1D()(squeezed)
        #wordsCNNPooled= MaxPooling1D(pool_size = int(squeezed.shape[1]), padding='valid')(squeezed)
        wordsCNNPooled = MaxPooling1D(pool_size=(numWordsPerSentence-(j+windowMin)+1))(wordsCNN)
        flattened = Lambda(lambda x: K.squeeze(x, 1))(wordsCNNPooled)
        maxPooledPerSentence.append(flattened)
        
    mergedPoolForSentence = Concatenate(axis = 1)(maxPooledPerSentence)
    newShape=(-1,1,int(mergedPoolForSentence.shape[1]))
    reshapedPoolForSentence = Lambda(lambda x: K.reshape(x,shape=newShape), name ='switch_axis_'+'sentence'+str(i+1)+'winSize'+str(j+windowMin))(mergedPoolForSentence)
    maxPooledPerDoc.append(reshapedPoolForSentence)
    
    densePoolForSentence = Dense(numDensePool, bias_regularizer=regularizers.l2(eta),
                                 kernel_regularizer=regularizers.l2(eta), activation='softmax', use_bias=True)(reshapedPoolForSentence)

    densePoolForSentence = Dropout(dr,name='DropDense'+str(i))(densePoolForSentence)
    scoresForSentences.append(densePoolForSentence)
    
#Naive Approach
averaged = Average()(scoresForSentences) 
averaged = Lambda(lambda x:K.reshape(x,shape=(-1,int(averaged.shape[1])*int(averaged.shape[2]))), name ='attend_output')(averaged)
out_avg = Dense(1, activation='sigmoid', use_bias=True)(averaged) 
    
#Apply Attention 
mergedPoolPerDoc = Concatenate(axis = 1)(maxPooledPerDoc)
biRnn_ = Bidirectional(GRU(dimGRU,  return_sequences=True), merge_mode='concat')(mergedPoolPerDoc)
newShape = (-1, int(mergedPoolPerDoc.shape[1]), int(biRnn_.shape[2]))
biRnn = Lambda(lambda x: K.reshape(x,shape=newShape), name ='biRnn_TF_Reminder1')(biRnn_)
#biRnn2 = Lambda(lambda x: K.reshape(x,shape=newShape), name ='biRnn_TF_Reminder2')(biRnn_[1])

#biRnn_cat = Concatenate(axis = 2)([biRnn1, biRnn2])

CONTEXT_DIM = 100

#eij = Dense(CONTEXT_DIM, use_bias=True, activation='tanh')(biRnn)
#eij = Dense(1, use_bias=False, activation='softmax')(eij)

#weighted_input = Dot(axes = 1)([eij, mergedPoolPerDoc])
#weighted_input = Lambda(lambda x: K.reshape(x,shape=(-1,int(weighted_input_.shape[1])*int(weighted_input_.shape[2]))), name ='attend_output')(weighted_input_)
eij_ = Dense(CONTEXT_DIM, use_bias=True, activation='tanh')(biRnn)
eij = Dense(1, use_bias=False, name = 'attention_weights',bias_regularizer=regularizers.l2(eta),
                                 kernel_regularizer=regularizers.l2(eta))(eij_)
eij_permuted = Permute((2,1))(eij)
eij_normalized = Activation('softmax',name = 'attention_softmax')(eij_permuted)
eij_normalized = Permute((2,1))(eij_normalized)

scoresPerDoc = Concatenate(axis = 1)(scoresForSentences)
weighted_input = Dot(axes = 1)([eij, mergedPoolPerDoc])
#weighted_input = Lambda(lambda x: K.reshape(x,shape=(-1,int(weighted_input_.shape[1])*int(weighted_input_.shape[2]))), name ='attend_output')(weighted_input_)
weighted_input = Lambda(lambda x: K.squeeze(x, 1), name='squeezeOutput')(weighted_input)

out = Dense(1, activation='sigmoid', use_bias=True)(weighted_input)

##

model = Model(input=[x_in], output=[out])#,weighted_input,eij_normalized])
#adadelta = keras.optimizers.Adadelta(lr=1.0, rho=0.95, epsilon=None, decay=0.0)
#model.compile(loss='binary_crossentropy',
#              optimizer=adadelta,
#              metrics=['accuracy'])
         
model.compile(loss='binary_crossentropy',
              optimizer=keras.optimizers.Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0),
              metrics=['accuracy'])

print("Attention Model Build Complete")
##
#model_avg = Model(inputs=[x_in], outputs=[out_avg])
#model_avg.compile(loss='binary_crossentropy',
#              optimizer=keras.optimizers.Adam(lr=0.0001, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0),
#              metrics=['accuracy'])

#print("Average Model Build Complete")
##
#save model to png file
#from keras.utils import plot_model
#plot_model( model, to_file='model.png' )

#モデルを保存せず直接可視化
#from IPython.display import SVG
#from keras.utils.vis_utils import model_to_dot
#SVG( model_to_dot( model ).create( prog='dot', format='svg' ) )
# Out:
# 40 15
# 61560 300
# Attention Model Build Complete
# /home/owner/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:126: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=[<tf.Tenso..., outputs=[<tf.Tenso...)`

# %%
maxPooledPerSentence
# Out:
# [<tf.Tensor 'lambda_237/Squeeze:0' shape=(?, 100) dtype=float32>,
#  <tf.Tensor 'lambda_238/Squeeze:0' shape=(?, 100) dtype=float32>,
#  <tf.Tensor 'lambda_239/Squeeze:0' shape=(?, 100) dtype=float32>,
#  <tf.Tensor 'lambda_240/Squeeze:0' shape=(?, 100) dtype=float32>]

# %%
save_model_path = '/home/owner/デスクトップ/milnet+edu/results/0724 (15,40)/lr = 0.001 with 10 units/params_adam_lle_docvec.hdf5'

# %%
#name = './params_milnet_adam_0720_3_adjCNN_fixed_weights.hdf5'
save_model = keras.callbacks.ModelCheckpoint(save_model_path, monitor='val_loss', verbose=1
                                             , save_best_only=True, save_weights_only=True, mode='min', period=1)

# %%
history_normal = model.fit(x_train, y_train, batch_size = batch_size, verbose=1, epochs=10 #epochs
                        ,validation_data=(x_valid,y_valid), shuffle=True, callbacks=[save_model])
# Out:
# Train on 210642 samples, validate on 25206 samples
# Epoch 1/10
# 210642/210642 [==============================] - 305s 1ms/step - loss: 0.4958 - acc: 0.8415 - val_loss: 0.4289 - val_acc: 0.8739
#
# Epoch 00001: val_loss improved from inf to 0.42892, saving model to /home/owner/デスクトップ/milnet+edu/results/0724 (15,40)/lr = 0.001 with 10 units/params_adam_normal_docvec.hdf5
# Epoch 2/10
# 210642/210642 [==============================] - 299s 1ms/step - loss: 0.4041 - acc: 0.8733 - val_loss: 0.3880 - val_acc: 0.8813
#
# Epoch 00002: val_loss improved from 0.42892 to 0.38801, saving model to /home/owner/デスクトップ/milnet+edu/results/0724 (15,40)/lr = 0.001 with 10 units/params_adam_normal_docvec.hdf5
# Epoch 3/10
# 210642/210642 [==============================] - 296s 1ms/step - loss: 0.3853 - acc: 0.8810 - val_loss: 0.3930 - val_acc: 0.8798
#
# Epoch 00003: val_loss did not improve
# Epoch 4/10
# 210642/210642 [==============================] - 295s 1ms/step - loss: 0.3776 - acc: 0.8852 - val_loss: 0.3738 - val_acc: 0.8844
#
# Epoch 00004: val_loss improved from 0.38801 to 0.37384, saving model to /home/owner/デスクトップ/milnet+edu/results/0724 (15,40)/lr = 0.001 with 10 units/params_adam_normal_docvec.hdf5
# Epoch 5/10
# 210642/210642 [==============================] - 295s 1ms/step - loss: 0.3692 - acc: 0.8904 - val_loss: 0.4015 - val_acc: 0.8757
#
# Epoch 00005: val_loss did not improve
# Epoch 6/10
# 210642/210642 [==============================] - 295s 1ms/step - loss: 0.3688 - acc: 0.8922 - val_loss: 0.3717 - val_acc: 0.8890
#
# Epoch 00006: val_loss improved from 0.37384 to 0.37174, saving model to /home/owner/デスクトップ/milnet+edu/results/0724 (15,40)/lr = 0.001 with 10 units/params_adam_normal_docvec.hdf5
# Epoch 7/10
# 210642/210642 [==============================] - 296s 1ms/step - loss: 0.3646 - acc: 0.8968 - val_loss: 0.3869 - val_acc: 0.8849
#
# Epoch 00007: val_loss did not improve
# Epoch 8/10
# 210642/210642 [==============================] - 295s 1ms/step - loss: 0.3637 - acc: 0.8976 - val_loss: 0.3803 - val_acc: 0.8892
#
# Epoch 00008: val_loss did not improve
# Epoch 9/10
# 210642/210642 [==============================] - 295s 1ms/step - loss: 0.3627 - acc: 0.8996 - val_loss: 0.3816 - val_acc: 0.8905
#
# Epoch 00009: val_loss did not improve
# Epoch 10/10
# 210642/210642 [==============================] - 295s 1ms/step - loss: 0.3608 - acc: 0.9012 - val_loss: 0.4286 - val_acc: 0.8686
#
# Epoch 00010: val_loss did not improve

# %%
history_LLE = model.fit(x_train, y_train, batch_size = batch_size, verbose=1, epochs=15 #epochs
                        ,validation_data=(x_valid,y_valid), shuffle=True, callbacks=[save_model])
# Out:
# Train on 210642 samples, validate on 25206 samples
# Epoch 1/15
#  92000/210642 [============>.................] - ETA: 2:50 - loss: 0.4168 - acc: 0.8408

# %%
model.load_weights(save_model_path)#('./params_milnet_adam_0718_2_fixed_weights.hdf5')

# %%
history_ISO = model.fit(x_train, y_train, batch_size = batch_size, verbose=1, epochs=15 #epochs
                        ,validation_data=(x_valid,y_valid), shuffle=True, callbacks=[save_model])
# Out:
# Train on 210642 samples, validate on 25206 samples
# Epoch 1/15
# 210642/210642 [==============================] - 360s 2ms/step - loss: 0.5562 - acc: 0.8407 - val_loss: 0.4690 - val_acc: 0.8724
#
# Epoch 00001: val_loss improved from inf to 0.46901, saving model to /home/owner/デスクトップ/milnet+edu/results/0724 (15,40)/lr = 0.001 with 10 units/params_adam_iso.hdf5
# Epoch 2/15
# 210642/210642 [==============================] - 356s 2ms/step - loss: 0.4566 - acc: 0.8718 - val_loss: 0.4689 - val_acc: 0.8673
#
# Epoch 00002: val_loss improved from 0.46901 to 0.46895, saving model to /home/owner/デスクトップ/milnet+edu/results/0724 (15,40)/lr = 0.001 with 10 units/params_adam_iso.hdf5
# Epoch 3/15
# 210642/210642 [==============================] - 355s 2ms/step - loss: 0.4408 - acc: 0.8777 - val_loss: 0.4454 - val_acc: 0.8759
#
# Epoch 00003: val_loss improved from 0.46895 to 0.44541, saving model to /home/owner/デスクトップ/milnet+edu/results/0724 (15,40)/lr = 0.001 with 10 units/params_adam_iso.hdf5
# Epoch 4/15
# 210642/210642 [==============================] - 355s 2ms/step - loss: 0.4339 - acc: 0.8817 - val_loss: 0.4534 - val_acc: 0.8722
#
# Epoch 00004: val_loss did not improve
# Epoch 5/15
# 210642/210642 [==============================] - 356s 2ms/step - loss: 0.4307 - acc: 0.8849 - val_loss: 0.4392 - val_acc: 0.8771
#
# Epoch 00005: val_loss improved from 0.44541 to 0.43917, saving model to /home/owner/デスクトップ/milnet+edu/results/0724 (15,40)/lr = 0.001 with 10 units/params_adam_iso.hdf5
# Epoch 6/15
# 210642/210642 [==============================] - 356s 2ms/step - loss: 0.4295 - acc: 0.8858 - val_loss: 0.4378 - val_acc: 0.8803
#
# Epoch 00006: val_loss improved from 0.43917 to 0.43781, saving model to /home/owner/デスクトップ/milnet+edu/results/0724 (15,40)/lr = 0.001 with 10 units/params_adam_iso.hdf5
# Epoch 7/15
# 210642/210642 [==============================] - 356s 2ms/step - loss: 0.4263 - acc: 0.8874 - val_loss: 0.4530 - val_acc: 0.8744
#
# Epoch 00007: val_loss did not improve
# Epoch 8/15
# 210642/210642 [==============================] - 355s 2ms/step - loss: 0.4250 - acc: 0.8892 - val_loss: 0.4391 - val_acc: 0.8807
#
# Epoch 00008: val_loss did not improve
# Epoch 9/15
# 210642/210642 [==============================] - 356s 2ms/step - loss: 0.4227 - acc: 0.8908 - val_loss: 0.4404 - val_acc: 0.8823
#
# Epoch 00009: val_loss did not improve
# Epoch 10/15
# 210642/210642 [==============================] - 355s 2ms/step - loss: 0.4217 - acc: 0.8917 - val_loss: 0.4409 - val_acc: 0.8815
#
# Epoch 00010: val_loss did not improve
# Epoch 11/15
# 210642/210642 [==============================] - 355s 2ms/step - loss: 0.4198 - acc: 0.8935 - val_loss: 0.4491 - val_acc: 0.8768
#
# Epoch 00011: val_loss did not improve
# Epoch 12/15
# 210642/210642 [==============================] - 355s 2ms/step - loss: 0.4189 - acc: 0.8943 - val_loss: 0.4412 - val_acc: 0.8835
#
# Epoch 00012: val_loss did not improve
# Epoch 13/15
# 210642/210642 [==============================] - 354s 2ms/step - loss: 0.4185 - acc: 0.8957 - val_loss: 0.4416 - val_acc: 0.8836
#
# Epoch 00013: val_loss did not improve
# Epoch 14/15
# 210642/210642 [==============================] - 355s 2ms/step - loss: 0.4174 - acc: 0.8968 - val_loss: 0.4452 - val_acc: 0.8838
#
# Epoch 00014: val_loss did not improve
# Epoch 15/15
# 210642/210642 [==============================] - 355s 2ms/step - loss: 0.4168 - acc: 0.8971 - val_loss: 0.4450 - val_acc: 0.8854
#
# Epoch 00015: val_loss did not improve

# %%
history = model_avg.fit(x_train, y_train, batch_size = batch_size, verbose=1, epochs=300 #epochs
                        , validation_data=(x_valid,y_valid), shuffle=True, callbacks=[save_model])

# %%
#plot history
import matplotlib.pyplot as plt
def plot_history(history):
    # 精度の履歴をプロット
    plt.plot(history.history['acc'],label="accuracy")
    plt.plot(history.history['val_acc'],"o-",label="val_acc")
    plt.title('model accuracy')
    plt.xlabel('epoch')
    plt.ylabel('accuracy')
    plt.legend(loc="lower right")
    plt.show()

    # 損失の履歴をプロット
    plt.plot(history.history['loss'],label="loss",)
    plt.plot(history.history['val_loss'],"o-",label="val_loss")
    plt.title('model loss')
    plt.xlabel('epoch')
    plt.ylabel('loss')
    plt.legend(loc='lower right')
    plt.show()

# %%
plot_history(history_normal)

# %%
save_model_path = '/home/owner/デスクトップ/milnet+edu/results/0724 (15,40)/lr = 0.001/params_adadelta_normal_0.3775_0.8758 .hdf5'
model.load_weights(save_model_path)#('./params_milnet_adam_0718_2_fixed_weights.hdf5')

# %%
score=model.evaluate(x_test, y_test)
# Out:
# 25510/25510 [==============================] - 41s 2ms/step

# %%
print(score[0],score[1])
# Out:
# 0.3688224749359978 0.8901999215993728

# %%
model.predict_on_batch(x_test[0:1])
# Out:
# array([[0.55685514]], dtype=float32)

# %%
##
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec

def plot_weights(w):
    l = len(w)
    fig = plt.figure(figsize=(10,16))
    gs = gridspec.GridSpec(int(l/2+1),2)
    
    for i in range(l):
        j = int( i/2 )
        k = i%2
        if k==0:
            ax = plt.subplot(gs[j,k])
            ax.hist( w[i].flatten() ,bins=100 ,range=(-0.5,0.5) )
            #ax.set_title(title[i])
        else:
            ax = plt.subplot(gs[j,k])
            ax.hist( w[i].flatten() ,bins=100 ,range=(-0.5,0.5) )
            #ax.set_title(title[i])
    plt.show()

save_model_path = '/home/owner/デスクトップ/milnet+edu/results/0724 (15,40)/params_adadelta_normal 0.489.hdf5'
model_test = Model(input=[x_in], output=[out,eij_normalized])
model_test.load_weights(save_model_path)
plot_weights(model_test.get_weights())
##
# Out:
# /home/owner/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:24: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=[<tf.Tenso..., outputs=[<tf.Tenso...)`

# %%
model.get_layer('dense_43').get_weights()
# Out:
# [array([[ 0.00613822, -0.01595823, -0.01638355, ..., -0.09339832,
#           0.23449233, -0.0163934 ],
#         [ 0.00570766, -0.01440853, -0.01028535, ...,  0.06878978,
#           0.02321846,  0.01221276],
#         [-0.00955735,  0.07102745,  0.05873981, ..., -0.04907799,
#          -0.11747277,  0.03790778],
#         ...,
#         [-0.01039937, -0.03331398, -0.03901637, ...,  0.07031082,
#           0.09033212, -0.02839166],
#         [-0.01678702,  0.02661383, -0.0132541 , ...,  0.0219114 ,
#          -0.02555005, -0.00124587],
#         [-0.00696072, -0.00591729, -0.00442338, ...,  0.14777248,
#          -0.08882821,  0.00289663]], dtype=float32),
#  array([-0.08097516,  0.00817164, -0.05212835,  0.00857434,  0.01582111,
#          0.00218245, -0.12096858,  0.06406359,  0.17368901, -0.06494537],
#        dtype=float32)]

# %%
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# Input (InputLayer)              (None, 40, 15)       0
# __________________________________________________________________________________________________
# convert_shape_sentence1 (Lambda (None, 15)           0           Input[0][0]
# __________________________________________________________________________________________________
# convert_shape_sentence2 (Lambda (None, 15)           0           Input[0][0]
# __________________________________________________________________________________________________
# convert_shape_sentence3 (Lambda (None, 15)           0           Input[0][0]
# __________________________________________________________________________________________________
# convert_shape_sentence4 (Lambda (None, 15)           0           Input[0][0]
# __________________________________________________________________________________________________
# convert_shape_sentence5 (Lambda (None, 15)           0           Input[0][0]
# __________________________________________________________________________________________________
# convert_shape_sentence6 (Lambda (None, 15)           0           Input[0][0]
# __________________________________________________________________________________________________
# convert_shape_sentence7 (Lambda (None, 15)           0           Input[0][0]
# __________________________________________________________________________________________________
# convert_shape_sentence8 (Lambda (None, 15)           0           Input[0][0]
# __________________________________________________________________________________________________
# convert_shape_sentence9 (Lambda (None, 15)           0           Input[0][0]
# __________________________________________________________________________________________________
# convert_shape_sentence10 (Lambd (None, 15)           0           Input[0][0]
# __________________________________________________________________________________________________
# convert_shape_sentence11 (Lambd (None, 15)           0           Input[0][0]
# __________________________________________________________________________________________________
# convert_shape_sentence12 (Lambd (None, 15)           0           Input[0][0]
# __________________________________________________________________________________________________
# convert_shape_sentence13 (Lambd (None, 15)           0           Input[0][0]
# __________________________________________________________________________________________________
# convert_shape_sentence14 (Lambd (None, 15)           0           Input[0][0]
# __________________________________________________________________________________________________
# convert_shape_sentence15 (Lambd (None, 15)           0           Input[0][0]
# __________________________________________________________________________________________________
# convert_shape_sentence16 (Lambd (None, 15)           0           Input[0][0]
# __________________________________________________________________________________________________
# convert_shape_sentence17 (Lambd (None, 15)           0           Input[0][0]
# __________________________________________________________________________________________________
# convert_shape_sentence18 (Lambd (None, 15)           0           Input[0][0]
# __________________________________________________________________________________________________
# convert_shape_sentence19 (Lambd (None, 15)           0           Input[0][0]
# __________________________________________________________________________________________________
# convert_shape_sentence20 (Lambd (None, 15)           0           Input[0][0]
# __________________________________________________________________________________________________
# convert_shape_sentence21 (Lambd (None, 15)           0           Input[0][0]
# __________________________________________________________________________________________________
# convert_shape_sentence22 (Lambd (None, 15)           0           Input[0][0]
# __________________________________________________________________________________________________
# convert_shape_sentence23 (Lambd (None, 15)           0           Input[0][0]
# __________________________________________________________________________________________________
# convert_shape_sentence24 (Lambd (None, 15)           0           Input[0][0]
# __________________________________________________________________________________________________
# convert_shape_sentence25 (Lambd (None, 15)           0           Input[0][0]
# __________________________________________________________________________________________________
# convert_shape_sentence26 (Lambd (None, 15)           0           Input[0][0]
# __________________________________________________________________________________________________
# convert_shape_sentence27 (Lambd (None, 15)           0           Input[0][0]
# __________________________________________________________________________________________________
# convert_shape_sentence28 (Lambd (None, 15)           0           Input[0][0]
# __________________________________________________________________________________________________
# convert_shape_sentence29 (Lambd (None, 15)           0           Input[0][0]
# __________________________________________________________________________________________________
# convert_shape_sentence30 (Lambd (None, 15)           0           Input[0][0]
# __________________________________________________________________________________________________
# convert_shape_sentence31 (Lambd (None, 15)           0           Input[0][0]
# __________________________________________________________________________________________________
# convert_shape_sentence32 (Lambd (None, 15)           0           Input[0][0]
# __________________________________________________________________________________________________
# convert_shape_sentence33 (Lambd (None, 15)           0           Input[0][0]
# __________________________________________________________________________________________________
# convert_shape_sentence34 (Lambd (None, 15)           0           Input[0][0]
# __________________________________________________________________________________________________
# convert_shape_sentence35 (Lambd (None, 15)           0           Input[0][0]
# __________________________________________________________________________________________________
# convert_shape_sentence36 (Lambd (None, 15)           0           Input[0][0]
# __________________________________________________________________________________________________
# convert_shape_sentence37 (Lambd (None, 15)           0           Input[0][0]
# __________________________________________________________________________________________________
# convert_shape_sentence38 (Lambd (None, 15)           0           Input[0][0]
# __________________________________________________________________________________________________
# convert_shape_sentence39 (Lambd (None, 15)           0           Input[0][0]
# __________________________________________________________________________________________________
# convert_shape_sentence40 (Lambd (None, 15)           0           Input[0][0]
# __________________________________________________________________________________________________
# Embedding (Embedding)           (None, 15, 300)      18468000    convert_shape_sentence1[0][0]
#                                                                  convert_shape_sentence1[0][0]
#                                                                  convert_shape_sentence1[0][0]
#                                                                  convert_shape_sentence2[0][0]
#                                                                  convert_shape_sentence2[0][0]
#                                                                  convert_shape_sentence2[0][0]
#                                                                  convert_shape_sentence3[0][0]
#                                                                  convert_shape_sentence3[0][0]
#                                                                  convert_shape_sentence3[0][0]
#                                                                  convert_shape_sentence4[0][0]
#                                                                  convert_shape_sentence4[0][0]
#                                                                  convert_shape_sentence4[0][0]
#                                                                  convert_shape_sentence5[0][0]
#                                                                  convert_shape_sentence5[0][0]
#                                                                  convert_shape_sentence5[0][0]
#                                                                  convert_shape_sentence6[0][0]
#                                                                  convert_shape_sentence6[0][0]
#                                                                  convert_shape_sentence6[0][0]
#                                                                  convert_shape_sentence7[0][0]
#                                                                  convert_shape_sentence7[0][0]
#                                                                  convert_shape_sentence7[0][0]
#                                                                  convert_shape_sentence8[0][0]
#                                                                  convert_shape_sentence8[0][0]
#                                                                  convert_shape_sentence8[0][0]
#                                                                  convert_shape_sentence9[0][0]
#                                                                  convert_shape_sentence9[0][0]
#                                                                  convert_shape_sentence9[0][0]
#                                                                  convert_shape_sentence10[0][0]
#                                                                  convert_shape_sentence10[0][0]
#                                                                  convert_shape_sentence10[0][0]
#                                                                  convert_shape_sentence11[0][0]
#                                                                  convert_shape_sentence11[0][0]
#                                                                  convert_shape_sentence11[0][0]
#                                                                  convert_shape_sentence12[0][0]
#                                                                  convert_shape_sentence12[0][0]
#                                                                  convert_shape_sentence12[0][0]
#                                                                  convert_shape_sentence13[0][0]
#                                                                  convert_shape_sentence13[0][0]
#                                                                  convert_shape_sentence13[0][0]
#                                                                  convert_shape_sentence14[0][0]
#                                                                  convert_shape_sentence14[0][0]
#                                                                  convert_shape_sentence14[0][0]
#                                                                  convert_shape_sentence15[0][0]
#                                                                  convert_shape_sentence15[0][0]
#                                                                  convert_shape_sentence15[0][0]
#                                                                  convert_shape_sentence16[0][0]
#                                                                  convert_shape_sentence16[0][0]
#                                                                  convert_shape_sentence16[0][0]
#                                                                  convert_shape_sentence17[0][0]
#                                                                  convert_shape_sentence17[0][0]
#                                                                  convert_shape_sentence17[0][0]
#                                                                  convert_shape_sentence18[0][0]
#                                                                  convert_shape_sentence18[0][0]
#                                                                  convert_shape_sentence18[0][0]
#                                                                  convert_shape_sentence19[0][0]
#                                                                  convert_shape_sentence19[0][0]
#                                                                  convert_shape_sentence19[0][0]
#                                                                  convert_shape_sentence20[0][0]
#                                                                  convert_shape_sentence20[0][0]
#                                                                  convert_shape_sentence20[0][0]
#                                                                  convert_shape_sentence21[0][0]
#                                                                  convert_shape_sentence21[0][0]
#                                                                  convert_shape_sentence21[0][0]
#                                                                  convert_shape_sentence22[0][0]
#                                                                  convert_shape_sentence22[0][0]
#                                                                  convert_shape_sentence22[0][0]
#                                                                  convert_shape_sentence23[0][0]
#                                                                  convert_shape_sentence23[0][0]
#                                                                  convert_shape_sentence23[0][0]
#                                                                  convert_shape_sentence24[0][0]
#                                                                  convert_shape_sentence24[0][0]
#                                                                  convert_shape_sentence24[0][0]
#                                                                  convert_shape_sentence25[0][0]
#                                                                  convert_shape_sentence25[0][0]
#                                                                  convert_shape_sentence25[0][0]
#                                                                  convert_shape_sentence26[0][0]
#                                                                  convert_shape_sentence26[0][0]
#                                                                  convert_shape_sentence26[0][0]
#                                                                  convert_shape_sentence27[0][0]
#                                                                  convert_shape_sentence27[0][0]
#                                                                  convert_shape_sentence27[0][0]
#                                                                  convert_shape_sentence28[0][0]
#                                                                  convert_shape_sentence28[0][0]
#                                                                  convert_shape_sentence28[0][0]
#                                                                  convert_shape_sentence29[0][0]
#                                                                  convert_shape_sentence29[0][0]
#                                                                  convert_shape_sentence29[0][0]
#                                                                  convert_shape_sentence30[0][0]
#                                                                  convert_shape_sentence30[0][0]
#                                                                  convert_shape_sentence30[0][0]
#                                                                  convert_shape_sentence31[0][0]
#                                                                  convert_shape_sentence31[0][0]
#                                                                  convert_shape_sentence31[0][0]
#                                                                  convert_shape_sentence32[0][0]
#                                                                  convert_shape_sentence32[0][0]
#                                                                  convert_shape_sentence32[0][0]
#                                                                  convert_shape_sentence33[0][0]
#                                                                  convert_shape_sentence33[0][0]
#                                                                  convert_shape_sentence33[0][0]
#                                                                  convert_shape_sentence34[0][0]
#                                                                  convert_shape_sentence34[0][0]
#                                                                  convert_shape_sentence34[0][0]
#                                                                  convert_shape_sentence35[0][0]
#                                                                  convert_shape_sentence35[0][0]
#                                                                  convert_shape_sentence35[0][0]
#                                                                  convert_shape_sentence36[0][0]
#                                                                  convert_shape_sentence36[0][0]
#                                                                  convert_shape_sentence36[0][0]
#                                                                  convert_shape_sentence37[0][0]
#                                                                  convert_shape_sentence37[0][0]
#                                                                  convert_shape_sentence37[0][0]
#                                                                  convert_shape_sentence38[0][0]
#                                                                  convert_shape_sentence38[0][0]
#                                                                  convert_shape_sentence38[0][0]
#                                                                  convert_shape_sentence39[0][0]
#                                                                  convert_shape_sentence39[0][0]
#                                                                  convert_shape_sentence39[0][0]
#                                                                  convert_shape_sentence40[0][0]
#                                                                  convert_shape_sentence40[0][0]
#                                                                  convert_shape_sentence40[0][0]
# __________________________________________________________________________________________________
# conv1d_4 (Conv1D)               (None, 13, 100)      90100       Embedding[0][0]
#                                                                  Embedding[3][0]
#                                                                  Embedding[6][0]
#                                                                  Embedding[9][0]
#                                                                  Embedding[12][0]
#                                                                  Embedding[15][0]
#                                                                  Embedding[18][0]
#                                                                  Embedding[21][0]
#                                                                  Embedding[24][0]
#                                                                  Embedding[27][0]
#                                                                  Embedding[30][0]
#                                                                  Embedding[33][0]
#                                                                  Embedding[36][0]
#                                                                  Embedding[39][0]
#                                                                  Embedding[42][0]
#                                                                  Embedding[45][0]
#                                                                  Embedding[48][0]
#                                                                  Embedding[51][0]
#                                                                  Embedding[54][0]
#                                                                  Embedding[57][0]
#                                                                  Embedding[60][0]
#                                                                  Embedding[63][0]
#                                                                  Embedding[66][0]
#                                                                  Embedding[69][0]
#                                                                  Embedding[72][0]
#                                                                  Embedding[75][0]
#                                                                  Embedding[78][0]
#                                                                  Embedding[81][0]
#                                                                  Embedding[84][0]
#                                                                  Embedding[87][0]
#                                                                  Embedding[90][0]
#                                                                  Embedding[93][0]
#                                                                  Embedding[96][0]
#                                                                  Embedding[99][0]
#                                                                  Embedding[102][0]
#                                                                  Embedding[105][0]
#                                                                  Embedding[108][0]
#                                                                  Embedding[111][0]
#                                                                  Embedding[114][0]
#                                                                  Embedding[117][0]
# __________________________________________________________________________________________________
# conv1d_5 (Conv1D)               (None, 12, 100)      120100      Embedding[1][0]
#                                                                  Embedding[4][0]
#                                                                  Embedding[7][0]
#                                                                  Embedding[10][0]
#                                                                  Embedding[13][0]
#                                                                  Embedding[16][0]
#                                                                  Embedding[19][0]
#                                                                  Embedding[22][0]
#                                                                  Embedding[25][0]
#                                                                  Embedding[28][0]
#                                                                  Embedding[31][0]
#                                                                  Embedding[34][0]
#                                                                  Embedding[37][0]
#                                                                  Embedding[40][0]
#                                                                  Embedding[43][0]
#                                                                  Embedding[46][0]
#                                                                  Embedding[49][0]
#                                                                  Embedding[52][0]
#                                                                  Embedding[55][0]
#                                                                  Embedding[58][0]
#                                                                  Embedding[61][0]
#                                                                  Embedding[64][0]
#                                                                  Embedding[67][0]
#                                                                  Embedding[70][0]
#                                                                  Embedding[73][0]
#                                                                  Embedding[76][0]
#                                                                  Embedding[79][0]
#                                                                  Embedding[82][0]
#                                                                  Embedding[85][0]
#                                                                  Embedding[88][0]
#                                                                  Embedding[91][0]
#                                                                  Embedding[94][0]
#                                                                  Embedding[97][0]
#                                                                  Embedding[100][0]
#                                                                  Embedding[103][0]
#                                                                  Embedding[106][0]
#                                                                  Embedding[109][0]
#                                                                  Embedding[112][0]
#                                                                  Embedding[115][0]
#                                                                  Embedding[118][0]
# __________________________________________________________________________________________________
# conv1d_6 (Conv1D)               (None, 11, 100)      150100      Embedding[2][0]
#                                                                  Embedding[5][0]
#                                                                  Embedding[8][0]
#                                                                  Embedding[11][0]
#                                                                  Embedding[14][0]
#                                                                  Embedding[17][0]
#                                                                  Embedding[20][0]
#                                                                  Embedding[23][0]
#                                                                  Embedding[26][0]
#                                                                  Embedding[29][0]
#                                                                  Embedding[32][0]
#                                                                  Embedding[35][0]
#                                                                  Embedding[38][0]
#                                                                  Embedding[41][0]
#                                                                  Embedding[44][0]
#                                                                  Embedding[47][0]
#                                                                  Embedding[50][0]
#                                                                  Embedding[53][0]
#                                                                  Embedding[56][0]
#                                                                  Embedding[59][0]
#                                                                  Embedding[62][0]
#                                                                  Embedding[65][0]
#                                                                  Embedding[68][0]
#                                                                  Embedding[71][0]
#                                                                  Embedding[74][0]
#                                                                  Embedding[77][0]
#                                                                  Embedding[80][0]
#                                                                  Embedding[83][0]
#                                                                  Embedding[86][0]
#                                                                  Embedding[89][0]
#                                                                  Embedding[92][0]
#                                                                  Embedding[95][0]
#                                                                  Embedding[98][0]
#                                                                  Embedding[101][0]
#                                                                  Embedding[104][0]
#                                                                  Embedding[107][0]
#                                                                  Embedding[110][0]
#                                                                  Embedding[113][0]
#                                                                  Embedding[116][0]
#                                                                  Embedding[119][0]
# __________________________________________________________________________________________________
# max_pooling1d_127 (MaxPooling1D (None, 1, 100)       0           conv1d_4[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_128 (MaxPooling1D (None, 1, 100)       0           conv1d_5[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_129 (MaxPooling1D (None, 1, 100)       0           conv1d_6[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_130 (MaxPooling1D (None, 1, 100)       0           conv1d_4[1][0]
# __________________________________________________________________________________________________
# max_pooling1d_131 (MaxPooling1D (None, 1, 100)       0           conv1d_5[1][0]
# __________________________________________________________________________________________________
# max_pooling1d_132 (MaxPooling1D (None, 1, 100)       0           conv1d_6[1][0]
# __________________________________________________________________________________________________
# max_pooling1d_133 (MaxPooling1D (None, 1, 100)       0           conv1d_4[2][0]
# __________________________________________________________________________________________________
# max_pooling1d_134 (MaxPooling1D (None, 1, 100)       0           conv1d_5[2][0]
# __________________________________________________________________________________________________
# max_pooling1d_135 (MaxPooling1D (None, 1, 100)       0           conv1d_6[2][0]
# __________________________________________________________________________________________________
# max_pooling1d_136 (MaxPooling1D (None, 1, 100)       0           conv1d_4[3][0]
# __________________________________________________________________________________________________
# max_pooling1d_137 (MaxPooling1D (None, 1, 100)       0           conv1d_5[3][0]
# __________________________________________________________________________________________________
# max_pooling1d_138 (MaxPooling1D (None, 1, 100)       0           conv1d_6[3][0]
# __________________________________________________________________________________________________
# max_pooling1d_139 (MaxPooling1D (None, 1, 100)       0           conv1d_4[4][0]
# __________________________________________________________________________________________________
# max_pooling1d_140 (MaxPooling1D (None, 1, 100)       0           conv1d_5[4][0]
# __________________________________________________________________________________________________
# max_pooling1d_141 (MaxPooling1D (None, 1, 100)       0           conv1d_6[4][0]
# __________________________________________________________________________________________________
# max_pooling1d_142 (MaxPooling1D (None, 1, 100)       0           conv1d_4[5][0]
# __________________________________________________________________________________________________
# max_pooling1d_143 (MaxPooling1D (None, 1, 100)       0           conv1d_5[5][0]
# __________________________________________________________________________________________________
# max_pooling1d_144 (MaxPooling1D (None, 1, 100)       0           conv1d_6[5][0]
# __________________________________________________________________________________________________
# max_pooling1d_145 (MaxPooling1D (None, 1, 100)       0           conv1d_4[6][0]
# __________________________________________________________________________________________________
# max_pooling1d_146 (MaxPooling1D (None, 1, 100)       0           conv1d_5[6][0]
# __________________________________________________________________________________________________
# max_pooling1d_147 (MaxPooling1D (None, 1, 100)       0           conv1d_6[6][0]
# __________________________________________________________________________________________________
# max_pooling1d_148 (MaxPooling1D (None, 1, 100)       0           conv1d_4[7][0]
# __________________________________________________________________________________________________
# max_pooling1d_149 (MaxPooling1D (None, 1, 100)       0           conv1d_5[7][0]
# __________________________________________________________________________________________________
# max_pooling1d_150 (MaxPooling1D (None, 1, 100)       0           conv1d_6[7][0]
# __________________________________________________________________________________________________
# max_pooling1d_151 (MaxPooling1D (None, 1, 100)       0           conv1d_4[8][0]
# __________________________________________________________________________________________________
# max_pooling1d_152 (MaxPooling1D (None, 1, 100)       0           conv1d_5[8][0]
# __________________________________________________________________________________________________
# max_pooling1d_153 (MaxPooling1D (None, 1, 100)       0           conv1d_6[8][0]
# __________________________________________________________________________________________________
# max_pooling1d_154 (MaxPooling1D (None, 1, 100)       0           conv1d_4[9][0]
# __________________________________________________________________________________________________
# max_pooling1d_155 (MaxPooling1D (None, 1, 100)       0           conv1d_5[9][0]
# __________________________________________________________________________________________________
# max_pooling1d_156 (MaxPooling1D (None, 1, 100)       0           conv1d_6[9][0]
# __________________________________________________________________________________________________
# max_pooling1d_157 (MaxPooling1D (None, 1, 100)       0           conv1d_4[10][0]
# __________________________________________________________________________________________________
# max_pooling1d_158 (MaxPooling1D (None, 1, 100)       0           conv1d_5[10][0]
# __________________________________________________________________________________________________
# max_pooling1d_159 (MaxPooling1D (None, 1, 100)       0           conv1d_6[10][0]
# __________________________________________________________________________________________________
# max_pooling1d_160 (MaxPooling1D (None, 1, 100)       0           conv1d_4[11][0]
# __________________________________________________________________________________________________
# max_pooling1d_161 (MaxPooling1D (None, 1, 100)       0           conv1d_5[11][0]
# __________________________________________________________________________________________________
# max_pooling1d_162 (MaxPooling1D (None, 1, 100)       0           conv1d_6[11][0]
# __________________________________________________________________________________________________
# max_pooling1d_163 (MaxPooling1D (None, 1, 100)       0           conv1d_4[12][0]
# __________________________________________________________________________________________________
# max_pooling1d_164 (MaxPooling1D (None, 1, 100)       0           conv1d_5[12][0]
# __________________________________________________________________________________________________
# max_pooling1d_165 (MaxPooling1D (None, 1, 100)       0           conv1d_6[12][0]
# __________________________________________________________________________________________________
# max_pooling1d_166 (MaxPooling1D (None, 1, 100)       0           conv1d_4[13][0]
# __________________________________________________________________________________________________
# max_pooling1d_167 (MaxPooling1D (None, 1, 100)       0           conv1d_5[13][0]
# __________________________________________________________________________________________________
# max_pooling1d_168 (MaxPooling1D (None, 1, 100)       0           conv1d_6[13][0]
# __________________________________________________________________________________________________
# max_pooling1d_169 (MaxPooling1D (None, 1, 100)       0           conv1d_4[14][0]
# __________________________________________________________________________________________________
# max_pooling1d_170 (MaxPooling1D (None, 1, 100)       0           conv1d_5[14][0]
# __________________________________________________________________________________________________
# max_pooling1d_171 (MaxPooling1D (None, 1, 100)       0           conv1d_6[14][0]
# __________________________________________________________________________________________________
# max_pooling1d_172 (MaxPooling1D (None, 1, 100)       0           conv1d_4[15][0]
# __________________________________________________________________________________________________
# max_pooling1d_173 (MaxPooling1D (None, 1, 100)       0           conv1d_5[15][0]
# __________________________________________________________________________________________________
# max_pooling1d_174 (MaxPooling1D (None, 1, 100)       0           conv1d_6[15][0]
# __________________________________________________________________________________________________
# max_pooling1d_175 (MaxPooling1D (None, 1, 100)       0           conv1d_4[16][0]
# __________________________________________________________________________________________________
# max_pooling1d_176 (MaxPooling1D (None, 1, 100)       0           conv1d_5[16][0]
# __________________________________________________________________________________________________
# max_pooling1d_177 (MaxPooling1D (None, 1, 100)       0           conv1d_6[16][0]
# __________________________________________________________________________________________________
# max_pooling1d_178 (MaxPooling1D (None, 1, 100)       0           conv1d_4[17][0]
# __________________________________________________________________________________________________
# max_pooling1d_179 (MaxPooling1D (None, 1, 100)       0           conv1d_5[17][0]
# __________________________________________________________________________________________________
# max_pooling1d_180 (MaxPooling1D (None, 1, 100)       0           conv1d_6[17][0]
# __________________________________________________________________________________________________
# max_pooling1d_181 (MaxPooling1D (None, 1, 100)       0           conv1d_4[18][0]
# __________________________________________________________________________________________________
# max_pooling1d_182 (MaxPooling1D (None, 1, 100)       0           conv1d_5[18][0]
# __________________________________________________________________________________________________
# max_pooling1d_183 (MaxPooling1D (None, 1, 100)       0           conv1d_6[18][0]
# __________________________________________________________________________________________________
# max_pooling1d_184 (MaxPooling1D (None, 1, 100)       0           conv1d_4[19][0]
# __________________________________________________________________________________________________
# max_pooling1d_185 (MaxPooling1D (None, 1, 100)       0           conv1d_5[19][0]
# __________________________________________________________________________________________________
# max_pooling1d_186 (MaxPooling1D (None, 1, 100)       0           conv1d_6[19][0]
# __________________________________________________________________________________________________
# max_pooling1d_187 (MaxPooling1D (None, 1, 100)       0           conv1d_4[20][0]
# __________________________________________________________________________________________________
# max_pooling1d_188 (MaxPooling1D (None, 1, 100)       0           conv1d_5[20][0]
# __________________________________________________________________________________________________
# max_pooling1d_189 (MaxPooling1D (None, 1, 100)       0           conv1d_6[20][0]
# __________________________________________________________________________________________________
# max_pooling1d_190 (MaxPooling1D (None, 1, 100)       0           conv1d_4[21][0]
# __________________________________________________________________________________________________
# max_pooling1d_191 (MaxPooling1D (None, 1, 100)       0           conv1d_5[21][0]
# __________________________________________________________________________________________________
# max_pooling1d_192 (MaxPooling1D (None, 1, 100)       0           conv1d_6[21][0]
# __________________________________________________________________________________________________
# max_pooling1d_193 (MaxPooling1D (None, 1, 100)       0           conv1d_4[22][0]
# __________________________________________________________________________________________________
# max_pooling1d_194 (MaxPooling1D (None, 1, 100)       0           conv1d_5[22][0]
# __________________________________________________________________________________________________
# max_pooling1d_195 (MaxPooling1D (None, 1, 100)       0           conv1d_6[22][0]
# __________________________________________________________________________________________________
# max_pooling1d_196 (MaxPooling1D (None, 1, 100)       0           conv1d_4[23][0]
# __________________________________________________________________________________________________
# max_pooling1d_197 (MaxPooling1D (None, 1, 100)       0           conv1d_5[23][0]
# __________________________________________________________________________________________________
# max_pooling1d_198 (MaxPooling1D (None, 1, 100)       0           conv1d_6[23][0]
# __________________________________________________________________________________________________
# max_pooling1d_199 (MaxPooling1D (None, 1, 100)       0           conv1d_4[24][0]
# __________________________________________________________________________________________________
# max_pooling1d_200 (MaxPooling1D (None, 1, 100)       0           conv1d_5[24][0]
# __________________________________________________________________________________________________
# max_pooling1d_201 (MaxPooling1D (None, 1, 100)       0           conv1d_6[24][0]
# __________________________________________________________________________________________________
# max_pooling1d_202 (MaxPooling1D (None, 1, 100)       0           conv1d_4[25][0]
# __________________________________________________________________________________________________
# max_pooling1d_203 (MaxPooling1D (None, 1, 100)       0           conv1d_5[25][0]
# __________________________________________________________________________________________________
# max_pooling1d_204 (MaxPooling1D (None, 1, 100)       0           conv1d_6[25][0]
# ...
# __________________________________________________________________________________________________
# dense_75 (Dense)                (None, 1, 10)        3010        switch_axis_sentence33winSize5[0]
# __________________________________________________________________________________________________
# dense_76 (Dense)                (None, 1, 10)        3010        switch_axis_sentence34winSize5[0]
# __________________________________________________________________________________________________
# dense_77 (Dense)                (None, 1, 10)        3010        switch_axis_sentence35winSize5[0]
# __________________________________________________________________________________________________
# dense_78 (Dense)                (None, 1, 10)        3010        switch_axis_sentence36winSize5[0]
# __________________________________________________________________________________________________
# dense_79 (Dense)                (None, 1, 10)        3010        switch_axis_sentence37winSize5[0]
# __________________________________________________________________________________________________
# dense_80 (Dense)                (None, 1, 10)        3010        switch_axis_sentence38winSize5[0]
# __________________________________________________________________________________________________
# dense_81 (Dense)                (None, 1, 10)        3010        switch_axis_sentence39winSize5[0]
# __________________________________________________________________________________________________
# dense_82 (Dense)                (None, 1, 10)        3010        switch_axis_sentence40winSize5[0]
# __________________________________________________________________________________________________
# DropDense0 (Dropout)            (None, 1, 10)        0           dense_43[0][0]
# __________________________________________________________________________________________________
# DropDense1 (Dropout)            (None, 1, 10)        0           dense_44[0][0]
# __________________________________________________________________________________________________
# DropDense2 (Dropout)            (None, 1, 10)        0           dense_45[0][0]
# __________________________________________________________________________________________________
# DropDense3 (Dropout)            (None, 1, 10)        0           dense_46[0][0]
# __________________________________________________________________________________________________
# DropDense4 (Dropout)            (None, 1, 10)        0           dense_47[0][0]
# __________________________________________________________________________________________________
# DropDense5 (Dropout)            (None, 1, 10)        0           dense_48[0][0]
# __________________________________________________________________________________________________
# DropDense6 (Dropout)            (None, 1, 10)        0           dense_49[0][0]
# __________________________________________________________________________________________________
# DropDense7 (Dropout)            (None, 1, 10)        0           dense_50[0][0]
# __________________________________________________________________________________________________
# DropDense8 (Dropout)            (None, 1, 10)        0           dense_51[0][0]
# __________________________________________________________________________________________________
# DropDense9 (Dropout)            (None, 1, 10)        0           dense_52[0][0]
# __________________________________________________________________________________________________
# DropDense10 (Dropout)           (None, 1, 10)        0           dense_53[0][0]
# __________________________________________________________________________________________________
# DropDense11 (Dropout)           (None, 1, 10)        0           dense_54[0][0]
# __________________________________________________________________________________________________
# DropDense12 (Dropout)           (None, 1, 10)        0           dense_55[0][0]
# __________________________________________________________________________________________________
# DropDense13 (Dropout)           (None, 1, 10)        0           dense_56[0][0]
# __________________________________________________________________________________________________
# DropDense14 (Dropout)           (None, 1, 10)        0           dense_57[0][0]
# __________________________________________________________________________________________________
# DropDense15 (Dropout)           (None, 1, 10)        0           dense_58[0][0]
# __________________________________________________________________________________________________
# DropDense16 (Dropout)           (None, 1, 10)        0           dense_59[0][0]
# __________________________________________________________________________________________________
# DropDense17 (Dropout)           (None, 1, 10)        0           dense_60[0][0]
# __________________________________________________________________________________________________
# DropDense18 (Dropout)           (None, 1, 10)        0           dense_61[0][0]
# __________________________________________________________________________________________________
# DropDense19 (Dropout)           (None, 1, 10)        0           dense_62[0][0]
# __________________________________________________________________________________________________
# DropDense20 (Dropout)           (None, 1, 10)        0           dense_63[0][0]
# __________________________________________________________________________________________________
# DropDense21 (Dropout)           (None, 1, 10)        0           dense_64[0][0]
# __________________________________________________________________________________________________
# DropDense22 (Dropout)           (None, 1, 10)        0           dense_65[0][0]
# __________________________________________________________________________________________________
# DropDense23 (Dropout)           (None, 1, 10)        0           dense_66[0][0]
# __________________________________________________________________________________________________
# DropDense24 (Dropout)           (None, 1, 10)        0           dense_67[0][0]
# __________________________________________________________________________________________________
# DropDense25 (Dropout)           (None, 1, 10)        0           dense_68[0][0]
# __________________________________________________________________________________________________
# DropDense26 (Dropout)           (None, 1, 10)        0           dense_69[0][0]
# __________________________________________________________________________________________________
# DropDense27 (Dropout)           (None, 1, 10)        0           dense_70[0][0]
# __________________________________________________________________________________________________
# DropDense28 (Dropout)           (None, 1, 10)        0           dense_71[0][0]
# __________________________________________________________________________________________________
# DropDense29 (Dropout)           (None, 1, 10)        0           dense_72[0][0]
# __________________________________________________________________________________________________
# DropDense30 (Dropout)           (None, 1, 10)        0           dense_73[0][0]
# __________________________________________________________________________________________________
# DropDense31 (Dropout)           (None, 1, 10)        0           dense_74[0][0]
# __________________________________________________________________________________________________
# DropDense32 (Dropout)           (None, 1, 10)        0           dense_75[0][0]
# __________________________________________________________________________________________________
# DropDense33 (Dropout)           (None, 1, 10)        0           dense_76[0][0]
# __________________________________________________________________________________________________
# DropDense34 (Dropout)           (None, 1, 10)        0           dense_77[0][0]
# __________________________________________________________________________________________________
# DropDense35 (Dropout)           (None, 1, 10)        0           dense_78[0][0]
# __________________________________________________________________________________________________
# DropDense36 (Dropout)           (None, 1, 10)        0           dense_79[0][0]
# __________________________________________________________________________________________________
# DropDense37 (Dropout)           (None, 1, 10)        0           dense_80[0][0]
# __________________________________________________________________________________________________
# DropDense38 (Dropout)           (None, 1, 10)        0           dense_81[0][0]
# __________________________________________________________________________________________________
# DropDense39 (Dropout)           (None, 1, 10)        0           dense_82[0][0]
# __________________________________________________________________________________________________
# concatenate_82 (Concatenate)    (None, 40, 10)       0           DropDense0[0][0]
#                                                                  DropDense1[0][0]
#                                                                  DropDense2[0][0]
#                                                                  DropDense3[0][0]
#                                                                  DropDense4[0][0]
#                                                                  DropDense5[0][0]
#                                                                  DropDense6[0][0]
#                                                                  DropDense7[0][0]
#                                                                  DropDense8[0][0]
#                                                                  DropDense9[0][0]
#                                                                  DropDense10[0][0]
#                                                                  DropDense11[0][0]
#                                                                  DropDense12[0][0]
#                                                                  DropDense13[0][0]
#                                                                  DropDense14[0][0]
#                                                                  DropDense15[0][0]
#                                                                  DropDense16[0][0]
#                                                                  DropDense17[0][0]
#                                                                  DropDense18[0][0]
#                                                                  DropDense19[0][0]
#                                                                  DropDense20[0][0]
#                                                                  DropDense21[0][0]
#                                                                  DropDense22[0][0]
#                                                                  DropDense23[0][0]
#                                                                  DropDense24[0][0]
#                                                                  DropDense25[0][0]
#                                                                  DropDense26[0][0]
#                                                                  DropDense27[0][0]
#                                                                  DropDense28[0][0]
#                                                                  DropDense29[0][0]
#                                                                  DropDense30[0][0]
#                                                                  DropDense31[0][0]
#                                                                  DropDense32[0][0]
#                                                                  DropDense33[0][0]
#                                                                  DropDense34[0][0]
#                                                                  DropDense35[0][0]
#                                                                  DropDense36[0][0]
#                                                                  DropDense37[0][0]
#                                                                  DropDense38[0][0]
#                                                                  DropDense39[0][0]
# __________________________________________________________________________________________________
# bidirectional_2 (Bidirectional) (None, 40, 100)      18300       concatenate_82[0][0]
# __________________________________________________________________________________________________
# biRnn_TF_Reminder1 (Lambda)     (None, 40, 100)      0           bidirectional_2[0][0]
# __________________________________________________________________________________________________
# dense_84 (Dense)                (None, 40, 100)      10100       biRnn_TF_Reminder1[0][0]
# __________________________________________________________________________________________________
# attention_weights (Dense)       (None, 40, 1)        100         dense_84[0][0]
# __________________________________________________________________________________________________
# permute_3 (Permute)             (None, 1, 40)        0           attention_weights[0][0]
# __________________________________________________________________________________________________
# attention_softmax (Activation)  (None, 1, 40)        0           permute_3[0][0]
# __________________________________________________________________________________________________
# permute_4 (Permute)             (None, 40, 1)        0           attention_softmax[0][0]
# __________________________________________________________________________________________________
# attention_mult (Dot)            (None, 10, 1)        0           concatenate_82[0][0]
#                                                                  permute_4[0][0]
# __________________________________________________________________________________________________
# squeezeOutput (Lambda)          (None, 10)           0           attention_mult[0][0]
# __________________________________________________________________________________________________
# dense_85 (Dense)                (None, 1)            11          squeezeOutput[0][0]
# ==================================================================================================
# Total params: 18,977,211
# Trainable params: 509,211
# Non-trainable params: 18,468,000
# __________________________________________________________________________________________________

# %%
history_normal2 = model.fit(x_train, y_train, batch_size = batch_size, verbose=1, initial_epoch=10,epochs=15 #epochs
                        ,validation_data=(x_valid,y_valid), shuffle=True, callbacks=[save_model])
# Out:
# Train on 210642 samples, validate on 25206 samples
# Epoch 11/15
# 210642/210642 [==============================] - 358s 2ms/step - loss: 0.3641 - acc: 0.8926 - val_loss: 0.3600 - val_acc: 0.8914
#
# Epoch 00011: val_loss improved from 0.36792 to 0.35997, saving model to /home/owner/デスクトップ/milnet+edu/results/0724 (15,40)/lr = 0.001 with 10 units/params_adam_normal.hdf5
# Epoch 12/15
# 210642/210642 [==============================] - 357s 2ms/step - loss: 0.3576 - acc: 0.8961 - val_loss: 0.3766 - val_acc: 0.8849
#
# Epoch 00012: val_loss did not improve
# Epoch 13/15
# 210642/210642 [==============================] - 358s 2ms/step - loss: 0.3558 - acc: 0.8977 - val_loss: 0.3654 - val_acc: 0.8908
#
# Epoch 00013: val_loss did not improve
# Epoch 14/15
# 210642/210642 [==============================] - 357s 2ms/step - loss: 0.3534 - acc: 0.9001 - val_loss: 0.3656 - val_acc: 0.8932
#
# Epoch 00014: val_loss did not improve
# Epoch 15/15
# 210642/210642 [==============================] - 358s 2ms/step - loss: 0.3519 - acc: 0.9016 - val_loss: 0.4007 - val_acc: 0.8752
#
# Epoch 00015: val_loss did not improve
